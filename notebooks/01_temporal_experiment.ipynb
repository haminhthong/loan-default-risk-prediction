# %% [markdown]
# # Thí nghiệm dự báo rủi ro theo thời gian
#
# Notebook này chỉ điều phối các hàm trong `src/`; không sao chép logic tiền xử lý hoặc huấn luyện.

# %%
from pathlib import Path
import sys

ROOT = Path.cwd().parent if Path.cwd().name == 'notebooks' else Path.cwd()
sys.path.insert(0, str(ROOT))

import pandas as pd
from src.data import load_data, temporal_split
from src.features import TARGET, build_features, create_target

# %% [markdown]
# ## Kiểm tra dữ liệu và split out-of-time
#
# Train dùng dữ liệu trước năm 2011; validation dùng nửa đầu 2011; test dùng nửa cuối 2011.

# %%
data_path = ROOT / 'data' / 'raw' / 'lendingclub_2007_2011.csv'
labeled = create_target(load_data(data_path))
train, validation, test = temporal_split(labeled)

pd.DataFrame({
    'split': ['train', 'validation', 'test'],
    'rows': [len(train), len(validation), len(test)],
    'default_rate': [train[TARGET].mean(), validation[TARGET].mean(), test[TARGET].mean()],
})

# %% [markdown]
# ## Huấn luyện chính thức
#
# Chạy lệnh sau từ thư mục gốc để sinh artifact và toàn bộ báo cáo:
#
# ```bash
# python -m src.train
# ```
#
# Kết quả được ghi vào `artifacts/` và `reports/`.
